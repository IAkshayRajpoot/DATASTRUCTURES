# %%
class Node: # node class
    def __init__(self, data):
        self.data=data  #assign data
        self.next=None  # next as null

# linked list class

class Linkedlist:
    def __init__(self): # function to initialize the linkedlist object
        self.head =None

# %%
class node: # node class
    def __init__(self, data):
        self.data=data  #assign data
        self.next=None  # next as null

# linked list class

class linkedlist:
    def __init__(self): # function to initialize the linkedlist object
        self.head =None
        self.tail=None
    def insertlast(self,data):
        newnode = node(data)
        if self.head==None:
            self.head=newnode
            self.tail=newnode
            return
        else:
            self.tail.next=newnode
            self.tail=newnode
            
    def printlist(self):
        temp= self.head
        n=0
        while(temp):
            print(temp.data)
            n = n+1
            temp = temp.next
        print('total', n) 
num = int(input("how many elements   "))        
        
l = linkedlist()
for i in range(num):
    l.insertlast(int(input("enter the elements  ")))

l.printlist()
# Out:
# how many elements   3
# enter the elements  3
# enter the elements  2
# enter the elements  1
# 3
# 2
# 1
# total 3

# %%
class Node: # node class
    def __init__(self, data):
        self.data=data  #assign data
        self.next=None  # next as null

# linked list class

class Linkedlist:
    def __init__(self): # function to initialize the linkedlist object
        self.head =None
        
    def printlist(self):
        temp= self.head
        n=0   # counter to count number of elements
        while(temp):
            n = n+1
            print(temp.data)
            temp = temp.next
        print(n)
        
if __name__ == '__main__':
    list = Linkedlist()
    
    list.head = Node(1)
    second= Node(2)
    third = Node(3)
    
    list.head.next=second;
    second.next=third;
    
    list.printlist()
# Out:
# 1
# 2
# 3
# 3

# %%
class node:
    def __init__(self,data):
        self.data=data
        self.next=None
class linkedlist:
    def __init__(self):
        self.head=None

    def insert(self,data):
        newnode=node(data)
        if self.head==None:
            self.head=newnode
        else:
            temp = self.head
            while temp.next!=None:
                temp=temp.next
            temp.next=newnode
    def search(self,item): # on unsorted linked list
        if self.head==None:
            print(empty)
        else:
            temp = self.head
            while(temp):
                if temp.data==item:
                    return True
                temp=temp.next
        return False   
l = linkedlist()

n = int(input("how many elements  :"))
for i in range(n):
    l.insert(int(input("enter elements   :")))
    
num = int(input("enter the element u want to search  :")) 
l.search(num)
# Out:
# how many elements  :7
# enter elements   :5
# enter elements   :6
# enter elements   :4
# enter elements   :8
# enter elements   :97
# enter elements   :1
# enter elements   :3
# enter the element u want to search  :8
# True

# %%
class node:
    def __init__(self, data):
        self.data = data
        self.next=None
class linkedlist:
    def __init__(self):
        self.head= None
    def insertAtlast(self, data):
        new_node = node(data)
        if(self.head==None):
            self.head=new_node
        else:
            temp = self.head
            while(temp.next!=None):
                temp = temp.next
            temp.next = new_node
    def delete(self):
        if self.head==None:
            print('empty')
        else:
            temp=self.head
            self.head=self.head.next
            
    def display(self):
        temp= self.head
        while(temp):
            print(temp.data)
            temp =temp.next
            
    def printlist(self):
        temp= self.head
        n=0   # counter to count number of elements
        while(temp):
            n = n+1
            temp = temp.next
        print('total', n) 
num = int(input("how many elements   "))        
        
l = linkedlist()
for i in range(num):
    l.insertAtlast(int(input("enter the elements  ")))

l.printlist()  
l.display()
l.delete()
print()
l.printlist()
print()
l.display()

# %%
class node:
    def __init__(self,data):
        self.data=data
        self.enxt=None
class linkedlist:
    def __init__(self):
        self.head=None
     
    def insertAtbeg(self,data):
        newnode=node(data)
        newnode.next=self.head
        self.head = newnode
    def printlist(self):
        temp= self.head
        while temp is not  None:
            print(temp.data)
            temp=temp.next
    def display(self):
        temp= self.head
        while(temp):
            print(temp.data)
            temp =temp.next
                   
                   
        
num = int(input('hoe much elements'))

l = linkedlist()
for i in range(num):
    l.insertAtbeg(int(input('enter element  : ')))
l.printlist()  
l.display()

# %%
class node:
    def __init__(self,data):
        self.data=data
        self.next=None
class linkedlist:
    def __init__(self):
        self.head=None
        
    def insertAtbeg(self,data):
        newnode=node(data)
        newnode.next=self.head
        self.head = newnode   
        
    def insertAfter(self,item, data):
        newnode=node(data)
        if self.head==None:
            self.head=newnode   
        else:
            temp=self.head
            while(temp):
                    if temp.data==item:
                        newnode.next=temp.next 
                        temp.next=newnode
                    temp=temp.next     
            
    def printlist(self):
        temp = self.head
        while(temp):
            print(temp.data)
            temp=temp.next
num = int(input('hoe much elements'))

l = linkedlist()
for i in range(num):
    l.insertAtbeg(int(input('enter element  : ')))            
            
l.printlist()             

n = int(input('enter the node after which u want to insert  :'))
m = int(input("enter node u want to insert :"))

l.insertAfter(n,m)
l.printlist()
# Out:
# hoe much elements5
# enter element  : 4
# enter element  : 5
# enter element  : 8
# enter element  : 7
# enter element  : 6
# 6
# 7
# 8
# 5
# 4
# enter the node after which u want to insert  :4
# enter node u want to insert :11
# 6
# 7
# 8
# 5
# 4
# 11

# %%
# deletion in linked list

class node:
    def __init__(self,data):
        self.data=data
        self.next=None
class linkedlist:
    def __init__(self):
        self.head=None
        
    def insertbeg(self,data):
        newnode=node(data)
        if self.head==None:
            self.head=newnode
        else:
            newnode.next=self.head
            self.head=newnode
    def delbeg(self):
            if self.head==None:
                print('empty list')
            else:
                temp=self.head
                self.head=self.head.next
                temp=None
    def printlist(self):
            temp=self.head
            count=0
            while(temp):
                count+=1
                print(temp.data)
                temp=temp.next
                
num = int(input('hoe much elements'))

l = linkedlist()
for i in range(num):
    l.insertbeg(int(input('enter element  : ')))   
    
l.printlist()

l.delbeg()
print('new list')
l.printlist()
# Out:
# hoe much elements3
# enter element  : 6
# enter element  : 5
# enter element  : 4
# 4
# 5
# 6
# new list
# 5
# 6

# %%
class node:
    def __init__(self,data):
        self.data=data
        self.next=None
class linkedlist:
    def __init__(self):
        self.head=None
     
    def insertlast(self,data):
        newnode=node(data)
        if self.head==None:
            self.head=newnode
        else:
            temp = self.head
            while(temp.next!=None):
                  temp = temp.next
            temp.next = newnode
        
           
            
    def dellast(self):
        if self.head==None:
            print('empty list')
        elif self.head.next==None:
            print('none')
        else:
            temp=self.head
            while(temp.next.next):
                temp=temp.next
            temp.next=None   
            
            
            
    def printlist(self):
        if self.head==None:
            print('empty list')
        else:
            temp=self.head
            while(temp):
                print(temp.data)
                temp=temp.next
num = int(input('hoe much elements'))

l = linkedlist()
for i in range(num):
    l.insertlast(int(input('enter element  : ')))   
    
l.printlist()

l.dellast()
print('new list')
l.printlist()
# Out:
# hoe much elements4
# enter element  : 1
# enter element  : 4
# enter element  : 4
# enter element  : 1
# 1
# 4
# 4
# 1
# new list
# 1
# 4
# 4

# %%
class node:
    def __init__(self,data):
        self.data=data
        self.next=None
class linkedlist:
    def __init__(self):
        self.head=None
     
    def insertlast(self,data):
        newnode=node(data)
        if self.head==None:
            self.head=newnode
        else:
            temp = self.head
            while(temp.next!=None):
                  temp = temp.next
            temp.next = newnode
            
    def insertafter(self,item,data):
        newnode=node(data)
        if self.head==None:
            self.head=newnode
        else:
            temp=self.head
            while(temp):
                if item==temp.data:
                    newnode.next=temp.next
                    temp.next=newnode
                temp=temp.next
                
    def delafter(self,key):
        temp=self.head
        if temp is not None:
            if temp.data == key:
                self.head=temp.next
                temp=None
                
            
        while(temp):
            if temp.data==key:
                break
            prev=temp
            temp=temp.next
        if temp==None: # if key is not in list
            return
        prev.next=temp.next
        temp=None
                    
                
    def printlist(self):
        temp = self.head
        while(temp):
            print(temp.data)
            temp=temp.next
num = int(input('hoe much elements'))

l = linkedlist()
for i in range(num):
    l.insertlast(int(input('enter element  : ')))            
            
l.printlist()             

n = int(input('enter the node after which u want to insert  : '))
m = int(input("enter node u want to insert : "))

l.insertafter(n,m)
l.printlist()

nm = int(input('enter the element u want to delete  : '))

l.delafter(nm)
print("after deletion")

l.printlist()
# Out:
# hoe much elements3
# enter element  : 4
# enter element  : 5
# enter element  : 6
# 4
# 5
# 6
# enter the node after which u want to insert  : 5
# enter node u want to insert : 1
# 4
# 5
# 1
# 6
# enter the element u want to delete  : 5
# after deletion
# 4
# 1
# 6

# %%
# insert and delete a node at a given position

class node:
    def __init__(self,data):
        self.data=data
        self.next=None
class linkedlist:
    def __init__(self):
        self.head=None
        self.size=0
        
  
        
    def insert(self,data):
        newnode = node(data)
        if self.head==None:
            self.head=newnode
        else:
            temp= self.head 
            while(temp.next !=None):
                temp=temp.next
            temp.next=newnode
            self.size=self.size+1
            print(self.size, 'check')
              
    def printlist(self):
        temp = self.head
        while(temp):
            print(temp.data)
            temp=temp.next
    def insertposition(self,pos,data):
        newnode=node(data)
        
        if pos==0:
            newnode.next=self.head
            self.head=newnode
        elif pos>self.size:
            print('out')
        elif pos==self.size:
            self.insert(data)
        else:
            temp=self.head
            count=0
            while(temp):
                if count==pos:
                    break
                pre=temp
                count+=1
                temp=temp.next
            newnode.next=temp.next
            pre.next=newnode
            
            
            
            
num = int(input('how much elements'))

l = linkedlist()
for i in range(num):
    l.insert(int(input('enter element  : ')))            
            
l.printlist()

nm = int(input('enter the position to insert  : '))
d=int(input('enter data  :'))
l.insertposition(nm,d)
l.printlist()
# Out:
# how much elements3
# enter element  : 4
# enter element  : 5
# 1 check
# enter element  : 8
# 2 check
# 4
# 5
# 8
# enter the position to insert  : 2
# enter data  :88
# 3 check
# 4
# 5
# 8
# 88

# %%
class node: # delete on given position
    def __init__(self,data):
        self.data=data
        self.next=None
        
class linkedlist:
    def __init__(self):
        self.head=None
        
    def insertlast(self, data):
        newnode=node(data)
        if self.head==None:
            self.head=newnode
        else:
            temp=self.head
            while(temp.next):
                temp=temp.next
            temp.next=newnode
            
    def delposition(self,pos):
        if self.head==None:
            print('empty list')
        elif pos==0:
            temp=self.head
            self.head=temp.next
            temp=None
        else:
            temp=self.head
            for i in range(pos-1):
                # find prev node
                temp=temp.next
                if temp==None:    
                    break
            if temp is None:
                print('position is more than number of node')
                return
            if temp.next==None: 
                print('node to be deleted doesnot exist')
                return
            next=temp.next.next
            temp.next=None
            temp.next=next
    
    def printlist(self):
        if self.head==None:
            print('empty')
        else:
            temp=self.head
            while(temp):
                print(temp.data)
                temp=temp.next
                
l=linkedlist()                
n =int(input('how many elements  : '))   
for i in range(n):
    l.insertlast(int(input('enter element : ')))
l.printlist() 

p=int(input('enter position to delete  : '))
l.delposition(p)
print('after del  ','\n')
l.printlist()
# Out:
# how many elements  : 3
# enter element : 4
# enter element : 5
# enter element : 6
# 4
# 5
# 6
# enter position to delete  : 1
# after del
#
# 4
# 6

# %%
# recursive methd to count total nodes
class node:
    def __init__(self,data):
        self.data=data
        self.next=None
        
class linkedlist:
    def __init__(self):
        self.head=None
        
    def insertlast(self, data):
        newnode=node(data)
        if self.head==None:
            self.head=newnode
        else:
            temp=self.head
            while(temp.next):
                temp=temp.next
            temp.next=newnode
    def getCountRec(self,node):
        if(not node):
            return 0
        else:
            return 1 + self.getCountRec(node.next)
    def getCount(self):
        return self.getCountRec(self.head)

            
l=linkedlist()                
n =int(input('how many elements  : '))   
for i in range(n):
    l.insertlast(int(input('enter element : '))) 
    
print('count = : ', l.getCount())
# Out:
# how many elements  : 3
# enter element : 4
# enter element : 5
# enter element : 6
# count = :  3

# %%
class node:
    def __init__(self,data):
        self.data=data
        self.next=None
        
class linkedlist:
    def __init__(self):
        self.head=None
        
    def insertlast(self, data):
        newnode=node(data)
        if self.head==None:
            self.head=newnode
        else:
            temp=self.head
            while(temp.next):
                temp=temp.next
            temp.next=newnode
    def search(self,key):
        flag=False
        
        if self.head==None:
            return False
        elif key==self.head.data:
             return True
        else:
            temp=self.head
            while(temp.next):
                if temp.data==key:
                    return True
                temp=temp.next
            return False
l=linkedlist()                
n =int(input('how many elements  : '))   
for i in range(n):
    l.insertlast(int(input('enter element : ')))
k = int(input('enter the node want to search  : '))    
if l.search(k)==True:
    print('yes')
else:
    print('no')
# Out:
# how many elements  : 1
# enter element : 2
# enter the node want to search  : 2
# yes

# %%
class node:  # serach nth element
    def __init__(self,data):
        self.data=data
        self.next=None
        
class linkedlist:
    def __init__(self):
        self.head=None
        
    def insertlast(self, data):
        newnode=node(data)
        if self.head==None:
            self.head=newnode
        else:
            temp=self.head
            while(temp.next):
                temp=temp.next
            temp.next=newnode
            
    def getSearch(self,key,node):
        if(not node):
            return False
        if(node.data==key):
            return True
        return self.getSearch(key,node.next)
    def search(self,a):
        return self.getSearch(a,self.head)
    
l=linkedlist()                
n =int(input('how many elements  : '))   
for i in range(n):
    l.insertlast(int(input('enter element : ')))

k = int(input('enter the node want to search  : '))    
if l.search(k)==True:
    print('yes')
else:
    print('no')
# Out:
# how many elements  : 1
# enter element : 2
# enter the node want to search  : 2
# yes

# %%
class node:
    def __init__(self,data):
        self.data=data
        self.next=None
        
class linkedlist:
    def __init__(self):
        self.head=None
        
    def insertlast(self, data):
        newnode=node(data)
        if self.head==None:
            self.head=newnode
        else:
            temp=self.head
            while(temp.next):
                temp=temp.next
            temp.next=newnode
    def getNth(self,index):
        if self.head==None:
            print('empty')
        else:
            temp=self.head
            count=1
            while(temp):
                if count==index:
                    print(temp.data)
                    break
                count+=1
                temp=temp.next   
l=linkedlist()                
n =int(input('how many elements  : '))   
for i in range(n):
    l.insertlast(int(input('enter element : ')))
    
k = int(input('enter the nth node   :'))
l.getNth(k)
# Out:
# how many elements  : 3
# enter element : 4
# enter element : 5
# enter element : 6
# enter the nth node   :3
# 6

# %%
class node: # find nth element (recurssive method)
    def __init__(self,data):
        self.data=data
        self.next=None
        
class linkedlist:
    def __init__(self):
        self.head=None
        
    def insertlast(self, data):
        newnode=node(data)
        if self.head==None:
            self.head=newnode
        else:
            temp=self.head
            while(temp.next):
                temp=temp.next
            temp.next=newnode
    def getNth(self,node,index):
        count=0
        if(node):
            if count==index:
                print(node.data)
                
            else:
                return self.getNth(node.next,index-1)
        else:
            print('index not exist')
    def getn(self,a):
        return self.getNth(self.head,a)
l=linkedlist()                
n =int(input('how many elements  : '))   
for i in range(n):
    l.insertlast(int(input('enter element : ')))
    
k = int(input('enter the index  :'))
l.getn(k)
# Out:
# how many elements  : 5
# enter element : 5
# enter element : 2
# enter element : 1
# enter element : 4
# enter element : 3
# enter the index  :2
# 1

# %%
# swapping of nodes in a linkedlist
# 10-15-12-13-20-14, x=12, y=20
# 10-15-20-13-12-14

class node:
    def __init__(self,data):
        self.data=data
        self.next=None
        
class linkedlist:
    def __init__(self):
        self.head=None
        
    def insertlast(self, data):
        newnode=node(data)
        if self.head==None:
            self.head=newnode
        else:
            temp=self.head
            while(temp.next):
                temp=temp.next
            temp.next=newnode
            
    def swapnode(self,x,y):
        if x==y:
            return
        # search for x
        prex=None
        curx=self.head
        while curx!=None and curx.data!=x:
            prex=curx
            curx=curx.next
            
        # search for y
        prey=None
        cury=self.head
        while cury!=None and cury.data!=y:
            prey=cury
            cury=cury.next    
            
        if cury==None or curx==None:
            return
            
        # if x is not head
        if prex!=None:
            prex.next=cury
        else:
            self.head=cury
        if prey!=None:
            prey.next=curx
        else:
            self.head=curx
        # swap next pointer    
        temp=curx.next
        curx.next=cury.next
        cury.next=temp
        
    def printlist(self):
        if self.head==None:
            print('empty')
        else:
            temp=self.head
            while(temp):
                print(temp.data)
                temp=temp.next    
        
l=linkedlist()                
n =int(input('how many elements  : '))   
for i in range(n):
    l.insertlast(int(input('enter element : ')))
l.printlist()    
    
o, p=[int(x) for x in input('enter nodes to swap  : ').split()]
l.swapnode(o,p)
l.printlist()
# Out:
# how many elements  : 5
# enter element : 4
# enter element : 5
# enter element : 6
# enter element : 1
# enter element : 2
# 4
# 5
# 6
# 1
# 2
# enter nodes to swap  : 4 6
# 6
# 5
# 4
# 1
# 2

# %%
# find the middle of a linkedlist

class node:
    def __init__(self,data):
        self.data=data
        self.next=None
        
class linkedlist:
    def __init__(self):
        self.head=None
        
    def insertlast(self, data):
        newnode=node(data)
        if self.head==None:
            self.head=newnode
        else:
            temp=self.head
            while(temp.next):
                temp=temp.next
            temp.next=newnode
            
    def getlength(self,node):
        if (not node):
            return 0
        else:
            return 1+self.getlength(node.next)
    def getl(self):
        return self.getlength(self.head)
    
    def printlist(self):
        if self.head==None:
            print('empty')
        else:
            temp=self.head
            while(temp):
                print(temp.data)
                temp=temp.next 
    def mid(self,ll):
        count=0
        temp=self.head
        while(temp is not None):
            if count==ll//2:
                return temp.data
            count+=1    
            temp=temp.next
            
        
 

l=linkedlist()                
n =int(input('how many elements  : '))   
for i in range(n):
    l.insertlast(int(input('enter element : ')))
l.printlist()    
print('len is ', l.getl())

length=l.getl()

print('mid is  ', l.mid(length))
# Out:
# how many elements  : 3
# enter element : 4
# enter element : 5
# enter element : 6
# 4
# 5
# 6
# len is  3
# mid is   5

# %%
# nth node from end 

class node:
    def __init__(self,data):
        self.data=data
        self.next=None
        
class linkedlist:
    def __init__(self):
        self.head=None
        
    def insertlast(self, data):
        newnode=node(data)
        if self.head==None:
            self.head=newnode
        else:
            temp=self.head
            while(temp.next):
                temp=temp.next
            temp.next=newnode
            
    def getlength(self,node):
        if (not node):
            return 0
        else:
            return 1+self.getlength(node.next)
    def getl(self):
        return self.getlength(self.head)
    
    def printlist(self):
        if self.head==None:
            print('empty')
        else:
            temp=self.head
            while(temp):
                print(temp.data)
                temp=temp.next
                
    def getNth(self,index):
        ind=(l.getl()-index+1)
        if self.head==None:
            print('empty list')
        else:
            temp=self.head
            count=1
            while(temp):
                if count==ind:
                    print(temp.data)
                    break
                count+=1
                temp=temp.next
        
        
                
                

l=linkedlist()                
n =int(input('how many elements  : '))   
for i in range(n):
    l.insertlast(int(input('enter element : ')))
l.printlist()    
print('len is ', l.getl())
k=int(input('enter nth node from last : '))
l.getNth(k)
# Out:
# how many elements  : 3
# enter element : 4
# enter element : 5
# enter element : 6
# 4
# 5
# 6
# len is  3
# enter nth node from last : 2
# 5

# %%
# to delete a linked list
class node:
    def __init__(self,data):
        self.data=data
        self.next=None
        
class linkedlist:
    def __init__(self):
        self.head=None
        
    def insertlast(self, data):
        newnode=node(data)
        if self.head==None:
            self.head=newnode
        else:
            temp=self.head
            while(temp.next):
                temp=temp.next
            temp.next=newnode
    def printlist(self):
        if self.head==None:
            print('empty')
        else:
            temp=self.head
            while(temp):
                print(temp.data)
                temp=temp.next 
                
    def dellast(self):
        if self.head is None:
            print('empty lis')
            
        else:
            temp=self.head
            while(temp.next):
                pre=temp
                temp=temp.next
            pre.next=None
            del temp
                
                
     
    
    
    
    
l=linkedlist()                
n =int(input('how many elements  : '))   
for i in range(n):
    l.insertlast(int(input('enter element : ')))
l.printlist()            
l.dellast()
l.printlist()
# Out:
# how many elements  : 3
# enter element : 3
# enter element : 2
# enter element : 1
# 3
# 2
# 1
# 3
# 2

# %%
class node:
    def __init__(self,data):
        self.data=data
        self.next=None
        
class linkedlist:
    def __init__(self):
        self.head=None
        
    def insertlast(self, data):
        newnode=node(data)
        if self.head==None:
            self.head=newnode
        else:
            temp=self.head
            while(temp.next):
                temp=temp.next
            temp.next=newnode
    def printlist(self):
        if self.head==None:
            print('empty')
        else:
            temp=self.head
            while(True):
                print(temp.data)
                temp=temp.next
                if temp==None:
                    break
    def getcountofnum(self,data):
        if self.head==None:
            print('emyt')
        else:
            temp=self.head
            count=0
            while(temp):
                if temp.data==data:
                    count+=1
                temp=temp.next 
            print('%d'%data,'occures','%d'%count, 'times')

                
                
                
    
l=linkedlist()                
n =int(input('how many elements  : '))   
for i in range(n):
    l.insertlast(int(input('enter element : ')))
l.printlist()    
d=int(input('enter the element : '))
l.getcountofnum(d)
# Out:
# how many elements  : 8
# enter element : 4
# enter element : 5
# enter element : 6
# enter element : 4
# enter element : 55
# enter element : 5
# enter element : 5
# enter element : 6
# 4
# 5
# 6
# 4
# 55
# 5
# 5
# 6
# enter the element : 5
# 5 occures 3 times

# %%
# reverse a singly linked list

class node:
    def __init__(self,data):
        self.data=data
        self.next=None
        
class linkedlist:
    def __init__(self):
        self.head=None
        
    def insertlast(self, data):
        newnode=node(data)
        if self.head==None:
            self.head=newnode
        else:
            temp=self.head
            while(temp.next):
                temp=temp.next
            temp.next=newnode
     
    def reverselist(self):
        if self.head is None:
            return "empty"
        else:
            temp=self.head
            while(temp):
                

    def printlist(self):
        if self.head==None:
            print('empty')
        else:
            temp=self.head
            while(True):
                print(temp.data)
                temp=temp.next
                if temp==None:
                    break
            
            
    
l=linkedlist()                
n =int(input('how many elements  : '))   
for i in range(n):
    l.insertlast(int(input('enter element : ')))
l.printlist()
# Out:
# how many elements  : 4
# enter element : 4
# enter element : 3
# enter element : 2
# enter element : 1
# 4
# 3
# 2
# 1

# %%
# circular linked list

class node:
    def __init__(self,data):
        self.data=data
        self.next=None
        
class linkedlist:
    def __init__(self):
        self.head=None
        
    def insertatbeg(self,data):
        newnode=node(data)
        temp=self.head
        newnode.next=self.head
        if self.head is not None:
            while(temp.next!=self.head):
                temp=temp.next
            temp.next=newnode
        else:
            newnode.next=newnode
            
        self.head=newnode   
            
    def printlist(self):
        if self.head==None:
            print('empty')
        else:
            temp=self.head
            while(True):
                print(temp.data)
                temp=temp.next
                if temp==self.head :
                    break
                
         
        
l=linkedlist()
n=int(input('how many '))
for i in range(n):
    l.insertatbeg(int(input('enter  ')))
l.printlist()
# Out:
# how many 3
# enter  4
# enter  5
# enter  5
# 5
# 5
# 4

# %%
# new type insertion 

class Node:
    def __init__(self,data):
        self.data = data
        self.next = None 
class Solution: 
    def display(self,head):
        current = head
        while current:
            print(current.data,end=' ')
            current = current.next
    def insert(self,head,data): 
        newnode=Node(data)
        if head:
            temp=head
            while(temp.next):
                temp=temp.next
            temp.next=newnode
            return head    
        else:              
            return newnode

mylist= Solution()
T=int(input('how many? : '))
head=None
for i in range(T):
    data=int(input('enter data : '))
    head=mylist.insert(head,data) 
mylist.display(head);
# Out:
# how many? : 4
# enter data : 5
# enter data : 7
# enter data : 8
# enter data : 9
# 5 7 8 9

# %%
class node:
    def __init__(self,data):
        self.data=data
        self.next=None
class linkedlist:
    def __init__(self):
        self.head=None

# %%
# reverse a linkedlist

class node:
    def __init__(self,data):
        self.data=data
        self.next=None
class linkedlist:
    def __init__(self):
        self.head=None
    def insertbeg(self,data):
        newnode = node(data)
        if self.head==None:
            self.head=newnode
            return
        else:
            newnode.next=self.head
            self.head=newnode
            return
    def printl(self):
        temp=self.head
        while(temp):
            print(temp.data)
            temp=temp.next
    def reversel(self):
        cur=self.head
        pre=nex=None
        while(cur):
            nex=cur.next
            cur.next=pre
            pre=cur
            cur=nex
        self.head=pre
        print(self.head.data)
            
            
n=int(input("how many? "))   
l = linkedlist()
for i in range(n):
    l.insertbeg(int(input("enter ")))
l.printl() 
l.reversel()
l.printl()
# Out:
# how many? 3
# enter 3
# enter 2
# enter 1
# 1
# 2
# 3
# 3
# 3
# 2
# 1

# %%
# Simple and tail recursive Python program to  
# reverse a linked list 
  
# Node class  
class Node: 
  
    # Constructor to initialize the node object 
    def __init__(self, data): 
        self.data = data 
        self.next = None
class LinkedList: 
  
    # Function to initialize head 
    def __init__(self): 
        self.head = None
  
  
    def reverseUtil(self, curr, prev): 
          
        # If last node mark it head 
        if curr.next is None : 
            self.head = curr  
              
            # Update next to prev node 
            curr.next = prev 
            return 
          
        # Save curr.next node for recursive call 
        next = curr.next
  
        # And update next  
        curr.next = prev 
      
        self.reverseUtil(next, curr)  
  
  
    # This function mainly calls reverseUtil() 
    # with previous as None 
    def reverse(self): 
        if self.head is None: 
            return 
        self.reverseUtil(self.head, None) 
  
  
    # Function to insert a new node at the beginning 
    def push(self, new_data): 
        new_node = Node(new_data) 
        new_node.next = self.head 
        self.head = new_node 
  
    # Utility function to print the linked LinkedList 
    def printList(self): 
        temp = self.head 
        while(temp): 
            print(temp.data), 
            temp = temp.next
  
  
# Driver program 
llist = LinkedList() 
llist.push(8) 
llist.push(7) 
llist.push(6) 
llist.push(5) 
llist.push(4) 
llist.push(3) 
llist.push(2) 
llist.push(1) 
  
print ("Given linked list")
llist.printList() 
  
llist.reverse() 
  
print ("\nReverse linked list")
llist.printList()
# Out:
# Given linked list
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
#
# Reverse linked list
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 1

# %%
# doubly linked list insertion

class node:
    def __init__(self,data):
        self.data=data
        self.next=None
        self.prev=None
class doublylist:
    def __init__(self):
        self.head=None
    
    def pushbeg(self, new_data): 
        new_node = node(data = new_data) 
        
        if self.head is not None: 
            self.head.prev = new_node
        new_node.next = self.head 
        new_node.prev = None
        self.head = new_node  
    def printl(self): 
        temp = self.head 
        while(temp): 
            print(temp.data), 
            temp = temp.next       
            
n=int(input("how many? "))   
l = doublylist()
for i in range(n):
    l.pushbeg(int(input("enter ")))
l.printl()  
print("head", l.head.data)
print(l.head.prev)
nn = l.head.next
print(l.head.next)
print(nn.prev)
# Out:
# how many? 3
# enter 3
# enter 2
# enter 1
# 1
# 2
# 3
# head 1
# None
# ...

# %%
class node:
    def __init__(self,data):
        self.data=data
        self.next=None
        self.prev=None
class doublylist:
    def __init__(self):
        self.head=None
    def insertbeg(self,data):
        newnode=node(data)
        
        if self.head==None:
            self.head = newnode
        else:
            newnode.next=self.head
            self.head.prev=newnode
            self.head=newnode

    def printl(self): 
        temp = self.head 
        print("Traversal in foeward direction")
        while(temp):
            print(temp.data)
            last=temp
            temp=temp.next
        print("traversal in backward direction")
        while(last):
            print(last.data)
            last=last.prev          
            
n=int(input("how many? "))   
l = doublylist()
for i in range(n):
    l.insertbeg(int(input("enter ")))
l.printl()  
print("head", l.head.data)
print(l.head.prev)
nn = l.head.next
print(l.head.next)
print(nn.prev)
# Out:
# how many? 3
# enter 3
# enter 2
# enter 1
# Traversal in foeward direction
# 1
# 2
# 3
# traversal in backward direction
# 3
# 2
# 1
# head 1
# None
# ...

# %%
class node:
    def __init__(self,data):
        self.data=data
        self.next=None
        self.prev=None
class doublylist:
    def __init__(self):
        self.head=None
     
    def insertend(self,data):
        newnode = node(data)
        
        if self.head==None:
            self.head=newnode
            
        else:
            temp=self.head
            while(temp.next):
                temp=temp.next
            temp.next=newnode
            newnode.prev=temp
    
    def printl(self): 
        temp = self.head 
        print("Traversal in foeward direction")
        while(temp):
            print(temp.data)
            last=temp
            temp=temp.next
        print("traversal in backward direction")
        while(last):
            print(last.data)
            last=last.prev           
            
n=int(input("how many? "))   
l = doublylist()
for i in range(n):
    l.insertend(int(input("enter ")))
l.printl()   
print(l.head.data)
# Out:
# how many? 4
# enter 4
# enter 3
# enter 2
# enter 1
# Traversal in foeward direction
# 4
# 3
# 2
# 1
# traversal in backward direction
# 1
# 2
# 3
# 4
# 4

# %%
## insertion after a given node

class node:
    def __init__(self,data):
        self.data=data
        self.next=None
        self.prev=None
class linkedlist:
    def __init__(self):
        self.head=None
     
    def insertlast(self,data):
        newnode=node(data)
        if self.head==None:
            self.head=newnode
        else:
            temp = self.head
            while(temp.next!=None):
                  temp = temp.next
            temp.next = newnode
            newnode.prev=temp
            
    def insertafter(self,item,data):
        newnode=node(data)
        temp=self.head
        while(temp):
            nex=temp.next
            if temp.data==item:
                newnode.next=temp.next
                newnode.prev=temp
                temp.next=newnode
                nex.prev=newnode
                #newnode.next.prev=newnode
            temp=temp.next 
        print("given node is not in DLL")    
       
                    
                
    def printlist(self):
        temp = self.head
        print("Traversal in forward direction")
        while(temp):
            print(temp.data)
            last=temp
            temp=temp.next
        print("traversal in backward direction")
        while(last):
            print(last.data)
            last=last.prev    
num = int(input('hoe much elements'))

l = linkedlist()
for i in range(num):
    l.insertlast(int(input('enter element  : ')))            
            
l.printlist()             

n = int(input('enter the node after which u want to insert  : '))
m = int(input("enter node u want to insert : "))

l.insertafter(n,m)
l.printlist()
# Out:
# hoe much elements3
# enter element  : 3
# enter element  : 2
# enter element  : 1
# Traversal in forward direction
# 3
# 2
# 1
# traversal in backward direction
# 1
# 2
# 3
# enter the node after which u want to insert  : 2
# enter node u want to insert : 33
# given node is not in DLL
# Traversal in forward direction
# 3
# 2
# 33
# 1
# traversal in backward direction
# 1
# 33
# 2
# 3

# %%
# Deletion in DLL

class node:
    def __init__(self,data):
        self.data=data
        self.next=None
        self.prev=None
class linkedlist:
    def __init__(self):
        self.head=None
     
    def insertlast(self,data):
        newnode=node(data)
        if self.head==None:
            self.head=newnode
        else:
            temp = self.head
            while(temp.next!=None):
                  temp = temp.next
            temp.next = newnode
            newnode.prev=temp
            
    def delbeg(self):
        if self.head==None:
            print("underflow")
            return
        else:
            temp=self.head
            temp.next.prev=None
            self.head=temp.next
            return
    def delend(self):
        if self.head==None:
            return "underflow"
        else:
            temp=self.head
            while(temp.next):
                pre=temp
                temp=temp.next
            pre.next=None
            del temp
    def delpos(self,pos):
        i=1
        if self.head==None:
            return "underflow"
        elif pos==1:
            self.delbeg()
        else:
            temp=self.head
            while(i<pos):
                pre=temp
                temp=temp.next
                i+=1
            pre.next=temp.next
            temp.next.prev=temp.prev
            
             
            
            
            
            
    def printlist(self):
        temp = self.head
        print("Traversal in forward direction")
        while(temp):
            print(temp.data)
            last=temp
            temp=temp.next
        print("traversal in backward direction")
        while(last):
            print(last.data)
            last=last.prev    
num = int(input('hoe much elements'))

l = linkedlist()
for i in range(num):
    l.insertlast(int(input('enter element  : ')))            
            
l.printlist()  
l.delbeg()
l.printlist()
l.delend()
l.printlist()
p = int(input("enter position: "))
l.delpos(p)
l.printlist()
# Out:
# hoe much elements6
# enter element  : 6
# enter element  : 5
# enter element  : 4
# enter element  : 3
# enter element  : 2
# enter element  : 1
# Traversal in forward direction
# 6
# 5
# 4
# 3
# 2
# 1
# traversal in backward direction
# 1
# 2
# 3
# 4
# 5
# 6
# Traversal in forward direction
# 5
# 4
# 3
# 2
# 1
# traversal in backward direction
# 1
# 2
# 3
# 4
# 5
# Traversal in forward direction
# 5
# 4
# 3
# 2
# traversal in backward direction
# 2
# 3
# 4
# 5
# enter position: 3
# Traversal in forward direction
# 5
# 4
# 2
# traversal in backward direction
# 2
# 4
# 5

# %%
# reverse a DLL

class node:
    def __init__(self,data):
        self.data=data
        self.next=None
        self.prev=None
class linkedlist:
    def __init__(self):
        self.head=None
     
    def insertlast(self,data):
        newnode=node(data)
        if self.head==None:
            self.head=newnode
        else:
            temp = self.head
            while(temp.next!=None):
                  temp = temp.next
            temp.next = newnode
            newnode.prev=temp
            
    def reversedll(self):
        cur=self.head
        nex=None
        while(cur):
            nex=cur.prev
            cur.prev=cur.next
            cur.next=nex
            pre=cur
            cur=cur.prev   
        self.head=pre    
            
    def printlist(self):
        temp = self.head
        print("Traversal in forward direction")
        while(temp):
            print(temp.data)
            last=temp
            temp=temp.next
        print("traversal in backward direction")
        while(last):
            print(last.data)
            last=last.prev    
num = int(input('hoe much elements'))

l = linkedlist()
for i in range(num):
    l.insertlast(int(input('enter element  : ')))            
            
l.printlist()
l.reversedll()
l.printlist()
# Out:
# hoe much elements3
# enter element  : 3
# enter element  : 2
# enter element  : 1
# Traversal in forward direction
# 3
# 2
# 1
# traversal in backward direction
# 1
# 2
# 3
# Traversal in forward direction
# 1
# 2
# 3
# traversal in backward direction
# 3
# 2
# 1

# %%
### insertion in circular list

class node:
    def __init__(self,data):
        self.data=data
        self.next=None
class circularlist:
    def __init__(self):
        self.head=None
        self.tail=None
        
    def insertlast(self,data):
        newnode = node(data)
        if self.head==None:
            self.head =self.tail = newnode
            self.tail.next= self.head
        else:
            self.tail.next = newnode
            self.tail = newnode
            self.tail.next = self.head
            
           
            
            
    def printcll(self):
        if self.head==None:
            return "underflow"
        else:
            temp=self.head

            while(temp.next != self.head):
                print(temp.data)
                temp=temp.next  
            print(temp.data)  
            
            
num = int(input('how much elements: '))                
l = circularlist()
for i in range(num):
    l.insertlast(int(input('enter element  : ')))            
print(l.tail.next.data)             
l.printcll()
# Out:
# how much elements: 3
# enter element  : 3
# enter element  : 2
# enter element  : 1
# 3
# 3
# 2
# 1

# %%
class node:
    def __init__(self,data):
        self.data=data
        self.next=None
    
class circularlist:
    def __init__(self):
        self.head=None
     
    def insertlast(self,data):
        newnode=node(data)
       
        if self.head==None:
            self.head=newnode
            self.head.next=newnode
            
        else:
            temp = self.head
            while(temp.next!=self.head):
                  temp = temp.next
            temp.next = newnode
            newnode.next = self.head
            print(newnode.next.data) 
            
    def insertbeg(self,data):
        newnode=node(data)
        if self.head==None:
            self.head=newnode
            self.head.next=self.head
            
        else:
            newnode.next=self.head.next
            self.head.next =newnode
            
            
    
    
            
    def traverse(self):  # only for insertbeg
        if (self.head == None): 
            print("List is empty") 
            return
  
        temp = self.head.next
        while temp: 
            print(temp.data, end = " ") 
            temp = temp.next
            if temp == self.head.next: 
                break
            
          
    
             
          
            
            
            
            
num = int(input('how much elements: '))                
l = circularlist()
for i in range(num):
    l.insertbeg(int(input('enter element  : ')))  

l.traverse()
# Out:
# how much elements: 4
# enter element  : 4
# enter element  : 3
# enter element  : 2
# enter element  : 1
# 1 2 3 4

# %%
class Node: 
    def __init__(self, data): 
        self.data = data 
        self.next = None
  
class CircularLinkedList: 
    def __init__(self): 
        self.last = None
  
    # This function is only for empty list 
    def addToEmpty(self, data): 
  
        if (self.last != None): 
            return self.last 
  
        # Creating the newnode temp 
        temp = Node(data) 
        self.last = temp 
  
        # Creating the link 
        self.last.next = self.last 
        return self.last 
  
    def addBegin(self, data): 
  
        if (self.last == None): 
            return self.addToEmpty(data) 
  
        temp = Node(data) 
        temp.next = self.last.next
        self.last.next = temp 
  
        return self.last 
  
    def addEnd(self, data): 
  
        if (self.last == None): 
            return self.addToEmpty(data) 
  
        temp = Node(data) 
        temp.next = self.last.next
        self.last.next = temp 
        self.last = temp 
  
        return self.last 
  
    def addAfter(self, data, item): 
  
        if (self.last == None): 
            return None
  
        temp = Node(data) 
        p = self.last.next
        while p: 
            if (p.data == item): 
                temp.next = p.next
                p.next = temp 
  
                if (p == self.last): 
                    self.last = temp 
                    return self.last 
                else: 
                    return self.last 
            p = p.next
            if (p == self.last.next): 
                print(item, "not present in the list") 
                break
  
    def traverse(self): 
        if (self.last == None): 
            print("List is empty") 
            return
  
        temp = self.last.next
        while temp: 
            print(temp.data, end = " ") 
            temp = temp.next
            if temp == self.last.next: 
                break
  
# Driver Code 
if __name__ == '__main__': 
  
    llist = CircularLinkedList() 
  
    last = llist.addToEmpty(6) 
    last = llist.addBegin(4) 
    last = llist.addBegin(2) 
    last = llist.addEnd(8) 
    last = llist.addEnd(12) 
    last = llist.addAfter(10,8) 
  
    llist.traverse()
# Out:
# 2 4 6 8 10 12

# %%
# reverse CLL
class node:
    def __init__(self,data):
        self.data=data
        self.next=None
        
class cll:
    def __init__(self):
        self.last = None
    def pushbeg(self,data):
        new = node(data)
        if self.last==None:
            self.last=new
            self.last.next=self.last
        
        else:
            new.next=self.last.next
            self.last.next =new
        print("last:  ",self.last.data) 
        
    def reversecll(self) :
        nex=None
        cur=self.last.next
        nex=cur.next
        if self.last==None:
            return "empty"
        while(cur !=self.last):
            pre=cur
            cur=nex
            nex=cur.next
            cur.next=pre
        nex.next=self.last
        self.last=nex
            
        
    def printcll(self):
        if self.last==None:
            return "underflow"
        else:
            temp=self.last.next
            while(temp):
                print(temp.data)
                temp=temp.next 
                if temp==self.last.next:
                    break
        
                
            
    
    
n = int(input("how many? "))  
c=cll()
for i in range(n):
    c.pushbeg(int(input("enter: ")))
c.printcll()  
c.reversecll()
c.printcll()
# Out:
# how many? 3
# enter: 3
# last:   3
# enter: 2
# last:   3
# enter: 1
# last:   3
# 1
# 2
# 3
# 3
# 2
# 1

# %% [markdown]
# # middle element in linkedlist

# %%
# not good for all cases

class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class linkedlist:
    def __init__(self):
        self.head = None
        
    def push(self, data):
        newnode = Node(data)
        if self.head == None:
            self.head = newnode
        else:
            temp= self.head
            while(temp.next):
                temp = temp.next
            temp.next = newnode
    def printlist(self):
        global count
        count = 0
        if self.head == None:
            print("empty")
        else:
            temp = self.head
            while(temp):
                count = count+1
                print(temp.data)
                temp = temp.next
            print("length: ", count)     
    def middle(self):
        l = count
        mid = round(count/2)
        c=0
        if self.head == None:
            print("empty")
        else:
            temp = self.head
            while(temp):
                c = c+1
                if c==mid:
                    print("mid: ", temp.data)
                temp = temp.next
        
                
n = int(input("how maany? ")) 

l = linkedlist()

for i in range(n):
    l.push(int(input("Enter Data:  ")))
    
l.printlist() 


l.middle()
# Out:
# how maany? 6
# Enter Data:  1
# Enter Data:  2
# Enter Data:  3
# Enter Data:  4
# Enter Data:  5
# Enter Data:  6
# 1
# 2
# 3
# 4
# 5
# 6
# length:  6
# mid:  3

# %%
# best way using two pointers

# your task is to complete this function
import math
'''
class node:
    def __init__(data):
        self.data = data
        self.next = None
'''

# function should return index to the any valid peak element
def findMid(head):
    fast=head
    slow=head
    while(fast is not None and fast.next is not None):
        slow=slow.next
        fast=fast.next.next
    return slow    
        

#{ 
#  Driver Code Starts
# Node Class    
class node:
    def __init__(self, val):
        self.data = val
        self.next = None
        
# Linked List Class
class Linked_List:
    def __init__(self):
        self.head = None
        self.tail = None

    def insert(self, val):
        if self.head == None:
            self.head = node(val)
            self.tail = self.head
        else:
            new_node = node(val)
            self.tail.next = new_node
            self.tail = self.tail.next

def createList(arr, n):
    lis = Linked_List()
    for i in range(n):
        lis.insert(arr[i])
    return lis.head

if __name__=='__main__':
    t = int(input("testcases?: "))
    for i in range(t):
        n = int(input("len: "))
        arr = list(map(int, input("enter data using space: ").strip().split()))
        head = createList(arr, n)
        print(findMid(head).data)




# } Driver Code Ends
# Out:
# testcases?: 1
# len: 3
# enter data using space: 1 2 3
# 2
